# %%
import pandas as pd
import matplotlib.pyplot as plt 
import matplotlib as mpl
import seaborn as sns
from pycaret.datasets import get_data 
from pycaret.anomaly import * 
mpl.rcParams['figure.dpi'] = 300
# Loading Dataset
numeric = ['Fresh','Milk','Grocery','Frozen','Detergents_Paper','Delicassen']
categorical = ['Channel','Region']
replace_dict = { "Channel": {1: "Horeca", 2: "Retail"},
                 "Region":  {1: "Lisbon", 2: "Oporto", 3: "Other"} }
data = get_data('wholesale', verbose = False)
data.replace(replace_dict, inplace = True)
# PyCaret environment setup
anomaly = setup(data, session_id = 8477)
# Out:
# <style type="text/css">
# #T_2df60_row6_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_2df60_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2df60_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2df60_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_2df60_row0_col1" class="data row0 col1" >8477</td>
#     </tr>
#     <tr>
#       <th id="T_2df60_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2df60_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_2df60_row1_col1" class="data row1 col1" >(440, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_2df60_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2df60_row2_col0" class="data row2 col0" >Transformed data shape</td>
#       <td id="T_2df60_row2_col1" class="data row2 col1" >(440, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_2df60_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2df60_row3_col0" class="data row3 col0" >Ordinal features</td>
#       <td id="T_2df60_row3_col1" class="data row3 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_2df60_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2df60_row4_col0" class="data row4 col0" >Numeric features</td>
#       <td id="T_2df60_row4_col1" class="data row4 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_2df60_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2df60_row5_col0" class="data row5 col0" >Categorical features</td>
#       <td id="T_2df60_row5_col1" class="data row5 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_2df60_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2df60_row6_col0" class="data row6 col0" >Preprocess</td>
#       <td id="T_2df60_row6_col1" class="data row6 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_2df60_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2df60_row7_col0" class="data row7 col0" >Imputation type</td>
#       <td id="T_2df60_row7_col1" class="data row7 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_2df60_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2df60_row8_col0" class="data row8 col0" >Numeric imputation</td>
#       <td id="T_2df60_row8_col1" class="data row8 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_2df60_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2df60_row9_col0" class="data row9 col0" >Categorical imputation</td>
#       <td id="T_2df60_row9_col1" class="data row9 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_2df60_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_2df60_row10_col0" class="data row10 col0" >Maximum one-hot encoding</td>
#       <td id="T_2df60_row10_col1" class="data row10 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_2df60_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_2df60_row11_col0" class="data row11 col0" >Encoding method</td>
#       <td id="T_2df60_row11_col1" class="data row11 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_2df60_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_2df60_row12_col0" class="data row12 col0" >CPU Jobs</td>
#       <td id="T_2df60_row12_col1" class="data row12 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_2df60_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_2df60_row13_col0" class="data row13 col0" >Use GPU</td>
#       <td id="T_2df60_row13_col1" class="data row13 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2df60_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_2df60_row14_col0" class="data row14 col0" >Log Experiment</td>
#       <td id="T_2df60_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2df60_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_2df60_row15_col0" class="data row15 col0" >Experiment Name</td>
#       <td id="T_2df60_row15_col1" class="data row15 col1" >anomaly-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_2df60_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_2df60_row16_col0" class="data row16 col0" >USI</td>
#       <td id="T_2df60_row16_col1" class="data row16 col1" >57ee</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Create Local Outlier Factor model with an outlier proportion of 10% and assign it to model variable
model = create_model('lof', fraction = 0.10)
# Out:
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
# Assign anomaly labels and scores to the data_assigned variable
data_assigned = assign_model(model)
data_assigned.head()
# Out:
#   Channel Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen  \
# 0  Retail  Other  12669  9656     7561     214              2674        1338
# 1  Retail  Other   7057  9810     9568    1762              3293        1776
# 2  Retail  Other   6353  8808     7684    2405              3516        7844
# 3  Horeca  Other  13265  1196     4221    6404               507        1788
# 4  Retail  Other  22615  5410     7198    3915              1777        5185
#
#    Anomaly  Anomaly_Score
# 0        0       1.107687
# 1        0       1.027102
# 2        0       1.398439
# 3        0       1.200384
# 4        0       1.164052

# %%
#Create new dataset of outliers named data_outliers
data_outliers = data_assigned.query('Anomaly == 1')

# %%
# Print first 5 instances of the outlier dataset
data_outliers.head(5)
# Out:
#    Channel Region  Fresh   Milk  Grocery  Frozen  Detergents_Paper  \
# 17  Horeca  Other   5876   6157     2933     839               370
# 23  Retail  Other  26373  36423    22019    5154              4337
# 47  Retail  Other  44466  54259    55571    7782             24171
# 56  Retail  Other   4098  29892    26866    2616             17740
# 61  Retail  Other  35942  38369    59598    3254             26701
#
#     Delicassen  Anomaly  Anomaly_Score
# 17        4478        1       1.458161
# 23       16523        1       2.249573
# 47        6465        1       3.224197
# 56        1340        1       1.529652
# 61        2017        1       2.799411

# %% [markdown]
# #SVM

# %%
# Create SVM model with an outlier proportion of 10% and assign it to model variable
svm = create_model('svm', fraction = 0.10)
# Out:
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
 #Assign anomaly labels and scores to the data_assigned variable
svm_data_assigned = assign_model(svm)
svm_data_assigned.head()
# Out:
#   Channel Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen  \
# 0  Retail  Other  12669  9656     7561     214              2674        1338
# 1  Retail  Other   7057  9810     9568    1762              3293        1776
# 2  Retail  Other   6353  8808     7684    2405              3516        7844
# 3  Horeca  Other  13265  1196     4221    6404               507        1788
# 4  Retail  Other  22615  5410     7198    3915              1777        5185
#
#    Anomaly  Anomaly_Score
# 0        0           -0.0
# 1        0           -0.0
# 2        0           -0.0
# 3        0           -0.0
# 4        0           -0.0

# %%
# Create new dataset of outliers named data_outliers
svm_data_outliers = svm_data_assigned.query('Anomaly == 1')

# %%
# Print first 5 instances of the outlier dataset
svm_data_outliers.head(5)
#svm does not pick up any outliers
# Out:
# Empty DataFrame
# Columns: [Channel, Region, Fresh, Milk, Grocery, Frozen, Detergents_Paper, Delicassen, Anomaly, Anomaly_Score]
# Index: []

# %% [markdown]
# #Iforest

# %%
# Create iForest model with an outlier proportion of 10% and assign it to model variable
iforest = create_model('iforest', fraction = 0.10)
# Out:
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
 #Assign anomaly labels and scores to the data_assigned variable
iforest_data_assigned = assign_model(iforest)
iforest_data_assigned.head()
# Out:
#   Channel Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen  \
# 0  Retail  Other  12669  9656     7561     214              2674        1338
# 1  Retail  Other   7057  9810     9568    1762              3293        1776
# 2  Retail  Other   6353  8808     7684    2405              3516        7844
# 3  Horeca  Other  13265  1196     4221    6404               507        1788
# 4  Retail  Other  22615  5410     7198    3915              1777        5185
#
#    Anomaly  Anomaly_Score
# 0        0      -0.142231
# 1        0      -0.146928
# 2        0      -0.068953
# 3        0      -0.166442
# 4        0      -0.062139

# %%
# Create new dataset of outliers named data_outliers
iforest_data_outliers = iforest_data_assigned.query('Anomaly == 1')

# %%
# Print first 5 instances of the outlier dataset
iforest_data_outliers.head(5)
# Out:
#    Channel Region  Fresh   Milk  Grocery  Frozen  Detergents_Paper  \
# 23  Retail  Other  26373  36423    22019    5154              4337
# 47  Retail  Other  44466  54259    55571    7782             24171
# 61  Retail  Other  35942  38369    59598    3254             26701
# 65  Retail  Other     85  20959    45828      36             24231
# 71  Horeca  Other  18291   1266    21042    5373              4173
#
#     Delicassen  Anomaly  Anomaly_Score
# 23       16523        1       0.069319
# 47        6465        1       0.166455
# 61        2017        1       0.116340
# 65        1423        1       0.043972
# 71       14472        1       0.021560

# %% [markdown]
# #ABOD

# %%
# Create ABOD model with an outlier proportion of 10% and assign it to model variable
abod = create_model('abod', fraction = 0.10)
# Out:
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
 #Assign anomaly labels and scores to the data_assigned variable
abod_data_assigned = assign_model(abod)
abod_data_assigned.head()
# Out:
#   Channel Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen  \
# 0  Retail  Other  12669  9656     7561     214              2674        1338
# 1  Retail  Other   7057  9810     9568    1762              3293        1776
# 2  Retail  Other   6353  8808     7684    2405              3516        7844
# 3  Horeca  Other  13265  1196     4221    6404               507        1788
# 4  Retail  Other  22615  5410     7198    3915              1777        5185
#
#    Anomaly  Anomaly_Score
# 0        0  -5.664320e-16
# 1        0  -1.723476e-15
# 2        0  -3.949763e-17
# 3        0  -1.465539e-15
# 4        0  -2.898443e-16

# %%
# Create new dataset of outliers named data_outliers
abod_data_outliers =abod_data_assigned.query('Anomaly == 1')

# %%
# Print first 5 instances of the outlier dataset
abod_data_outliers.head(5)
# Out:
#    Channel Region  Fresh   Milk  Grocery  Frozen  Detergents_Paper  \
# 23  Retail  Other  26373  36423    22019    5154              4337
# 39  Horeca  Other  56159    555      902   10002               212
# 45  Retail  Other   5181  22044    21531    1740              7353
# 47  Retail  Other  44466  54259    55571    7782             24171
# 56  Retail  Other   4098  29892    26866    2616             17740
#
#     Delicassen  Anomaly  Anomaly_Score
# 23       16523        1  -4.124037e-20
# 39        2916        1  -2.620307e-17
# 45        4985        1  -3.469083e-17
# 47        6465        1  -7.848227e-20
# 56        1340        1  -1.134013e-17

# %% [markdown]
# #KNN

# %%
# Create KNN model with an outlier proportion of 10% and assign it to model variable
knn= create_model('knn', fraction = 0.10)
# Out:
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
 #Assign anomaly labels and scores to the data_assigned variable
knn_data_assigned = assign_model(knn)
knn_data_assigned.head()
# Out:
#   Channel Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen  \
# 0  Retail  Other  12669  9656     7561     214              2674        1338
# 1  Retail  Other   7057  9810     9568    1762              3293        1776
# 2  Retail  Other   6353  8808     7684    2405              3516        7844
# 3  Horeca  Other  13265  1196     4221    6404               507        1788
# 4  Retail  Other  22615  5410     7198    3915              1777        5185
#
#    Anomaly  Anomaly_Score
# 0        0    4412.718437
# 1        0    3893.808290
# 2        0    6837.430877
# 3        0    3621.922694
# 4        0    5769.670874

# %%
# Create new dataset of outliers named data_outliers
knn_data_outliers =abod_data_assigned.query('Anomaly == 1')

# %%
# Print first 5 instances of the outlier dataset
knn_data_outliers.head(5)
# Out:
#    Channel Region  Fresh   Milk  Grocery  Frozen  Detergents_Paper  \
# 23  Retail  Other  26373  36423    22019    5154              4337
# 39  Horeca  Other  56159    555      902   10002               212
# 45  Retail  Other   5181  22044    21531    1740              7353
# 47  Retail  Other  44466  54259    55571    7782             24171
# 56  Retail  Other   4098  29892    26866    2616             17740
#
#     Delicassen  Anomaly  Anomaly_Score
# 23       16523        1  -4.124037e-20
# 39        2916        1  -2.620307e-17
# 45        4985        1  -3.469083e-17
# 47        6465        1  -7.848227e-20
# 56        1340        1  -1.134013e-17
